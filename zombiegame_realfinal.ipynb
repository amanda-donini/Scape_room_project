# %%
#importing cool stuff

import time
import sys
import random

def print_typewriter(text, delay=0.03):
    for char in text:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(delay)
    print()
    
def print_typewriter2(text, delay=0.000001):
    for char in text:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(delay)
    
def print_shaking_text(text, iterations=20, delay=0.05):
    for _ in range(iterations):
        shaking_text = ""
        for char in text:
            shaking_text += char + " " * random.randint(1, 3)  # Add random spaces
        sys.stdout.write("\r" + shaking_text)
        sys.stdout.flush()
        time.sleep(delay)

#global variables and such

potion = """
      _____
     `.___,'
      (___)
      <   >
       ) (
      /`-.\
     /     \
    / _    _\
   :,' `-.' `:
   |         |
   :         ;
    \       /
     `.___.' SSt

"""

sword = """

              /\                               ______,....----,
/VVVVVVVVVVVVVV|===================""""""""""""       ___,..-'
`^^^^^^^^^^^^^^|======================----------""""""
              \/

"""

zombie = "(¬º-°)¬"
player_name = ""
        
haunted_house = """
      _____________
    /  DA PT AUG23 \\
   / Zombie Mansion \\
  /______Team 2______\\
   ||  || /--\\ ||  ||
   ||[]|| | .| ||[]||
 ()||__||_|__|_||__||()
( )|-|-|-|====|-|-|-|( ) 
^^^^^^^^^^====^^^^^^^^^^^
"""

zombie_mansion = """
▒███████▒ ▒█████   ███▄ ▄███▓ ▄▄▄▄    ██▓▓█████     ███▄ ▄███▓ ▄▄▄       ███▄    █   ██████  ██▓ ▒█████   ███▄    █ 
▒ ▒ ▒ ▄▀░▒██▒  ██▒▓██▒▀█▀ ██▒▓█████▄ ▓██▒▓█   ▀    ▓██▒▀█▀ ██▒▒████▄     ██ ▀█   █ ▒██    ▒ ▓██▒▒██▒  ██▒ ██ ▀█   █ 
░ ▒ ▄▀▒░ ▒██░  ██▒▓██    ▓██░▒██▒ ▄██▒██▒▒███      ▓██    ▓██░▒██  ▀█▄  ▓██  ▀█ ██▒░ ▓██▄   ▒██▒▒██░  ██▒▓██  ▀█ ██▒
  ▄▀▒   ░▒██   ██░▒██    ▒██ ▒██░█▀  ░██░▒▓█  ▄    ▒██    ▒██ ░██▄▄▄▄██ ▓██▒  ▐▌██▒  ▒   ██▒░██░▒██   ██░▓██▒  ▐▌██▒
▒███████▒░ ████▓▒░▒██▒   ░██▒░▓█  ▀█▓░██░░▒████▒   ▒██▒   ░██▒ ▓█   ▓██▒▒██░   ▓██░▒██████▒▒░██░░ ████▓▒░▒██░   ▓██░
░▒▒ ▓░▒░▒░ ▒░▒░▒░ ░ ▒░   ░  ░░▒▓███▀▒░▓  ░░ ▒░ ░   ░ ▒░   ░  ░ ▒▒   ▓▒█░░ ▒░   ▒ ▒ ▒ ▒▓▒ ▒ ░░▓  ░ ▒░▒░▒░ ░ ▒░   ▒ ▒ 
░░▒ ▒ ░ ▒  ░ ▒ ▒░ ░  ░      ░▒░▒   ░  ▒ ░ ░ ░  ░   ░  ░      ░  ▒   ▒▒ ░░ ░░   ░ ▒░░ ░▒  ░ ░ ▒ ░  ░ ▒ ▒░ ░ ░░   ░ ▒░
░ ░ ░ ░ ░░ ░ ░ ▒  ░      ░    ░    ░  ▒ ░   ░      ░      ░     ░   ▒      ░   ░ ░ ░  ░  ░   ▒ ░░ ░ ░ ▒     ░   ░ ░ 
  ░ ░        ░ ░         ░    ░       ░     ░  ░          ░         ░  ░         ░       ░   ░      ░ ░           ░ 
░                                  ░                                                                                
                                                                                                                    
"""

knife = """
       .---.
       |---|
       |---|
       |---|
   .---^ - ^---.
   :___________:
      |  |//|
      |  |//|
      |  |//|
      |  |//|
      |  |//|
      |  |//|
      |  |.-|
      |.-'**|
       \***/
        \*/
         V
"""

skeleton_viking = """
                              _.--""-._
  .                         ."         ".
 / \    ,^.         /(     Y             |      )\
/   `---. |--'\    (  \__..'--   -   -- -'""-.-'  )
|        :|    `>   '.     l_..-------.._l      .'
|      __l;__ .'      "-.__.||_.-'v'-._||`"----"
 \  .-' | |  `              l._       _.'
  \/    | |                   l`^^'^^'j
        | |                _   \_____/     _
        j |               l `--__)-'(__.--' |
        | |               | /`---``-----'"1 |  ,-----.
        | |               )/  `--' '---'   \'-'  ___  `-.
        | |              //  `-'  '`----'  /  ,-'   I`.  \
      _ L |_            //  `-.-.'`-----' /  /  |   |  `. \
     '._' / \         _/(   `/   )- ---' ;  /__.J   L.__.\ :
      `._;/7(-.......'  /        ) (     |  |            | |
      `._;l _'--------_/        )-'/     :  |___.    _._./ ;
        | |                 .__ )-'\  __  \  \  I   1   / /
        `-'                /   `-\-(-'   \ \  `.|   | ,' /
                           \__  `-'    __/  `-. `---'',-'
                              )-._.-- (        `-----'
                             )(  l\ o ('..-.
                       _..--' _'-' '--'.-. |
                __,,-'' _,,-''            \ \
               f'. _,,-'                   \ \
              ()--  |                       \ \
                \.  |                       /  \
                  \ \                      |._  |
                   \ \                     |  ()|
                    \ \                     \  /
                     ) `-.                   | |
                    // .__)                  | |
                 _.//7'                      | |
               '---'                         j_| `
                                            (| |
                                             |  \
                                             |lllj
                                             |||||  -nabis
"""
# define rooms and items

#Game Room
game_room = {
    "name": "dark basement",
    "type": "room",
}

couch = {
    "name": "couch",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

pile_of_bones = {
    "name": "pile of bones",
    "type": "furniture",
}

bloody_cupboard = {
    "name": "bloody cupboard",
    "type": "furniture",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

#Bedroom 1

bedroom_1 = {
    "name": "crazy hallway",
    "type": "room",
}

queen_bed = {
    "name": "closet",
    "type": "furniture",
}

door_b = {
    "name": "door b",
    "type": "door",
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

door_c = {
    "name": "door c",
    "type": "door",
}

#bedroom 2

bedroom_2 = {
    "name": "treasure room",
    "type": "room",
}

double_bed = {
    "name": "golden chest",
    "type": "furniture",
}

door_b = {
    "name": "door b",
    "type": "door",
}

dresser = {
    "name": "first aid kit",
    "type": "furniture",
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

door_d = {
    "name": "door d",
    "type": "door",
}

#Living_room:

living_room = {
    "name": "final room",
    "type": "room",
}

dining_table = {
    "name": "armory box",
    "type": "furniture",
}

door_d = {
    "name": "door d",
    "type": "door",
}

key_d = {
    "name": "key door d",
    "type": "key",
    "target": door_d,
}

outside = {
    "name": "outside",
}

all_rooms = [game_room, bedroom_1, bedroom_2, living_room, outside]

all_doors = [door_a, door_b, door_c, door_d]

# define which items/rooms are related

object_relations = {
    "dark basement": [couch, pile_of_bones, door_a, bloody_cupboard],
    "pile of bones": [key_a],
    "door a": [game_room, bedroom_1],
    "crazy hallway": [queen_bed, door_b, door_c],
    "closet": [key_b],
    "door b": [bedroom_1, bedroom_2],
    "door c": [bedroom_1, living_room],
    "treasure room": [dresser, double_bed, door_b],
    "golden chest": [key_c],
    "first aid kit": [key_d],
    "final room": [dining_table, door_d],
    "door d": [outside],
    "outside": [door_a],
}

# define game state. Do not directly change this dict.
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This
# way you can replay the game multiple times.

INIT_GAME_STATE = {"current_room": game_room, "keys_collected": [],
  "target_room": outside
}

# %%
def linebreak():
    """

    Print a line break
    """
    print("\n\n")

def start_game():
    """
    Start the game
    """
    print_typewriter("You wake up in pool of zombie acid, stinking of rotten flesh and teared limbs")
    print_typewriter("Your eyes still hurt from the acid fumes but you see letters written in blood in front of you")
    print_typewriter("You manage to open your eyes and... Oh My God! Noooo!! Where am I?")
    print_typewriter("While your eyes get better you manage to read the bloody text")
    print_typewriter2(zombie_mansion)
    global player_name
    player_name = input("Enter player name:")
    print_shaking_text(f"Welcome, {player_name}, goodluck!")
    linebreak()
    play_room(game_state["current_room"])

def play_room(room):
    """
    Play a room. First check if the room being played is the target room.
    If it is, the game will end with success. Otherwise, let player either
    explore (list all items in this room) or examine an item found here.
    """
    game_state["current_room"] = room
    if(game_state["current_room"] == game_state["target_room"]):
        ze_encounter2()
        print_typewriter("Congratulations!!! You have beat ''Zombie Mansion''.")
        print_typewriter("Ending credits will follow")
        print_typewriter("Ironhack DA PT AUG2023 Team 2")
        print()
        print_typewriter("Special thanks to the developers:")
        print_typewriter("Marina")
        print_typewriter("Pedro")
        print_typewriter("Maria")
        print_typewriter("Amanda")
        print_typewriter("Geert")
        
    else:
        print_typewriter("Current level: " + room["name"])
        intended_action = input(f"What would you like to do, {player_name} ? Type 'explore' or 'examine'?").strip()
        
        print()
        
        if intended_action == "explore":
            explore_room(room)
            play_room(room)
        elif intended_action == "examine":
            examine_item(input("What would you like to examine?").strip())
            
            print()
            
        else:
            print("Not sure what you mean. Type 'explore' or 'examine'.")
            play_room(room)
        linebreak()

def explore_room(room):
    """
    Explore a room. List all items belonging to this room.
    """
    items = [i["name"] for i in object_relations[room["name"]]]
    print("You explore the room. This is " + room["name"] + ". You find " + ", ".join(items))

def get_next_room_of_door(door, current_room):
    """
    From object_relations, find the two rooms connected to the given door.
    Return the room that is not the current_room.
    """
    connected_rooms = object_relations[door["name"]]
    for room in connected_rooms:
        if(not current_room == room):
            return room

def examine_item(item_name):
    """
    Examine an item which can be a door or furniture.
    First make sure the intended item belongs to the current room.
    Then check if the item is a door. Tell player if key hasn't been
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.
    """
    current_room = game_state["current_room"]
    next_room = ""
    output = None

    for item in object_relations[current_room["name"]]:
        if(item["name"] == item_name):
            output = "You examine " + item_name + ". "
            if(item["type"] == "door"):
                have_key = False
                for key in game_state["keys_collected"]:
                    if(key["target"] == item):
                        have_key = True
                if(have_key):
                    output += "You unlock it with a key you have."
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    output += "It is locked but you don't have the key."
            else:
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0):
                    item_found = object_relations[item["name"]].pop()
                    game_state["keys_collected"].append(item_found)
                    if item["name"] == "first aid kit":
                        output += "You find " + item_found["name"] + " and a potion, you drink it. It not only recovers your health but also increases your max health to 100!"
                        print(potion)
                    elif item["name"] == "closet":
                        output += "The zombie is dead now, it drops" + item_found["name"] + "."
                        ze_encounter()   
                    elif item["name"] == "armory box":
                        output += "You try to open the box"
                        riddle_2()
                    else:
                        output += "You find " + item_found["name"] + "."
                elif item["name"] == "bloody cupboard":
                    riddle_1()
                else:
                    output += "You try to open the box."
                    riddle_2()
            print(output)
            linebreak()
            break

    if(output is None):
        print_typewriter("The item you requested is not found in the current room.")

    if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'):
        play_room(next_room)
    else:
        play_room(current_room)

#i added bloody cupboard and riddle_1

def riddle_1():
    confirm = input("You see a text written with blood, do you want to look closer? Enter 'yes' or 'no' ")
    if confirm == 'yes':
        print_typewriter("You look closer and the bloody text says: 'People buy me to eat, but never eat me. I am very sharp, what am i?' ")
        answer = input("You also see a blood-stained keyboard, what do you want to enter?:")
        print()
        if answer.lower() == 'knife':
            print_typewriter("Smart, you find the knife and equip it, might come in handy later!")
            print(knife)
            print()
        else:
            print("Think again...")
    else:
        print("COWARD!")

#riddle2

def riddle_2():
    confirm = input("Do you want to open the armory box? Enter 'yes' or 'no' ")
    if confirm == 'yes':
        print_typewriter("The box is locked with a password.")
        answer = input("I'm tall when I'm young, and I'm short when I'm old. I burn. What am i? ")
        print()
        if answer.lower() == 'candle':
            print_typewriter("CORRECT! The armory box opens. You take our a huge sword and your attack power doubles!")
            print(sword)
            print()
        else:
            print("Think again...")
    else:
        print("COWARD!")
        
#zombie encounters


def ze_encounter():

    player_john_doe = 50   # name and health points can be changed
    zé_the_zombie = 20     # name and health points can be changed

    print_typewriter(f"As soon as {player_name} opens the closet, {player_name} is confronted by a terrified monster known as Zé the Zombie. {player_name} has two obvious options: flee or fight")
    print(zombie)
 
    while player_john_doe > 0 and zé_the_zombie > 0:
        print_typewriter(f"{player_name} Health: {player_john_doe}")
        print_typewriter(f"Zé the Zombie Health: {zé_the_zombie}\n")

        act= input('type flee or fight to proceed')
        act= act.lower()

        if act == "fight":
            john_doe_att = random.randint(8, 15)   # attack damage can be changed
            zé_att = random.randint(5, 10)         # attack damage can be changed

            zé_the_zombie -= john_doe_att
            player_john_doe -= zé_att

            print("You attack the Zé the Zombie and did", john_doe_att,"damage")
            print("Zé bite you for", zé_att,"damage" )
        elif act == "flee":
            print_typewriter("You tried to run away, but theres no place to run... Game Over!")
            start_game()
        else:
            print_typewriter("Invalid action. Choose 'fight' or 'flee'.")


    if player_john_doe <= 0:
        print_typewriter("You were defeated by the zombie. Game over.")
    elif zé_the_zombie <= 0:
        print_typewriter("Congratulations! You have defeated the zombie.")

        
def ze_encounter2():

    player_john_doe = 100   # name and health points can be changed
    zé_the_zombie = 70     # name and health points can be changed
    print(skeleton_viking)
    print_typewriter(f"{player_name} tries to open the door, but Zabina the Skeleton falls from the ceiling. {player_name} has two obvious options: flee or fight")

 
    while player_john_doe > 0 and zé_the_zombie > 0:
        print_typewriter(f"{player_name} Health: {player_john_doe}")
        print_typewriter(f"Zabina the Zombie Health: {zé_the_zombie}\n")

        act= input('type flee or fight to proceed')
        act= act.lower()

        if act == "fight":
            john_doe_att = random.randint(15, 25)   # attack damage can be changed
            zé_att = random.randint(5, 10)         # attack damage can be changed

            zé_the_zombie -= john_doe_att
            player_john_doe -= zé_att

            print("You attack the Zé the Zombie and did", john_doe_att,"damage")
            print("Zé bite you for", zé_att,"damage" )
        elif act == "flee":
            print_typewriter("You tried to run away, but theres no place to run... Game Over!")
            start_game()
        else:
            print_typewriter("Invalid action. Choose 'fight' or 'flee'.")


    if player_john_doe <= 0:
        print_typewriter("You were defeated by the zombie. Game over.")
    elif zé_the_zombie <= 0:
        print_typewriter("That was so tough but you are happy that you have defeated the skeleton zombie.")

# %%
game_state = {"current_room": game_room, "keys_collected": [],
  "target_room": outside}

# %%
start_game()
# Out:
# You wake up in pool of zombie acid, stinking of rotten flesh and teared limbs
# Your eyes still hurt from the acid fumes but you see letters written in blood in front of you
# You manage to open your eyes and... Oh My God! Noooo!! Where am I?
# While your eyes get better you manage to read the bloody text
#
# ▒███████▒ ▒█████   ███▄ ▄███▓ ▄▄▄▄    ██▓▓█████     ███▄ ▄███▓ ▄▄▄       ███▄    █   ██████  ██▓ ▒█████   ███▄    █
# ▒ ▒ ▒ ▄▀░▒██▒  ██▒▓██▒▀█▀ ██▒▓█████▄ ▓██▒▓█   ▀    ▓██▒▀█▀ ██▒▒████▄     ██ ▀█   █ ▒██    ▒ ▓██▒▒██▒  ██▒ ██ ▀█   █
# ░ ▒ ▄▀▒░ ▒██░  ██▒▓██    ▓██░▒██▒ ▄██▒██▒▒███      ▓██    ▓██░▒██  ▀█▄  ▓██  ▀█ ██▒░ ▓██▄   ▒██▒▒██░  ██▒▓██  ▀█ ██▒
#   ▄▀▒   ░▒██   ██░▒██    ▒██ ▒██░█▀  ░██░▒▓█  ▄    ▒██    ▒██ ░██▄▄▄▄██ ▓██▒  ▐▌██▒  ▒   ██▒░██░▒██   ██░▓██▒  ▐▌██▒
# ▒███████▒░ ████▓▒░▒██▒   ░██▒░▓█  ▀█▓░██░░▒████▒   ▒██▒   ░██▒ ▓█   ▓██▒▒██░   ▓██░▒██████▒▒░██░░ ████▓▒░▒██░   ▓██░
# ...
